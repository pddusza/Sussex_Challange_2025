# %%
import os
datapath = "/net/tscratch/people/plgjsikora/data"

# %%
import numpy as np
import pandas as pd
from keras.utils import to_categorical

class SHLDataProviderRaw:
  def __init__(self, root_path:str, flag: str, mode: str, location: str = "Hips", sensor: str = "Acc_x", silent = True, four_locs = False):
    '''
    | Setup data provider for SHL 2025 Challenge
    | Args:
    | root_path: path to root data folder
    | flag: one of train, validation, test
    | mode: one of singlefile, singlefolder, all
    | location: where to load from (Hips/Bag etc)
    | sensor: which file to load (Acc_x/Mag_z etc)
    | silent: supress print statements
    | Example usage:
    | provider = SHLDataProviderRaw(datapath, "train", "singlefolder", location="Bag")
    | x, y = provider.load_data()
    '''
    self.mode = mode.lower()
    self.flag = flag.lower()
    self.location = location.capitalize()
    self.sensor = sensor.capitalize()
    self.silent = silent
    if self.flag not in ["test", "train", "validation"]:
      raise ValueError(f"Unexpected flag received: got {self.flag}")
    if self.mode not in ["singlefile", "singlefolder", "all"]:
      raise ValueError(f"Unexpected mode received: got {self.mode}")
    if self.flag == 'train' and four_locs:
      self.datapath = os.path.join(root_path, "train_4_locations")
    else:
      self.datapath = os.path.join(root_path, self.flag)

  def load_data(self):
    if self.mode == "singlefile":
      x_data, y_data = self._load_from_file()
    elif self.mode == "singlefolder":
      x_data, y_data = self._load_from_folder()
    elif self.mode == "all":
      x_data, y_data = self._load_all()
    return np.array(x_data), np.array(y_data)

  def _load_label_file(self, labelpath):
      if not self.silent:
        print(f"Loading labels from: {labelpath}")
      y_data = np.loadtxt(labelpath, dtype=int)
      y_data[np.isnan(y_data)] = 1
      y_data = np.median(y_data, axis=1).astype(int)
      y_data = y_data - 1
      y_data = to_categorical(y_data, len(np.unique(y_data)))
      return y_data

  def _load_location_data(self, path):
      def load_txt_csv(path):
            if not self.silent:
                print(f"Loading data from: {path}")
            if self.flag == 'test':
                np_data = np.loadtxt(path, dtype=np.float32, delimiter=",")
            else:
                df = pd.read_csv(path, header=None, delim_whitespace=True, engine='python')
                np_data = df.to_numpy()
            return np_data
      acc_x = load_txt_csv(f'{path}/Acc_x.txt')
      acc_y = load_txt_csv(f'{path}/Acc_y.txt')
      acc_z = load_txt_csv(f'{path}/Acc_z.txt')
      gyr_x = load_txt_csv(f'{path}/Gyr_x.txt')
      gyr_y = load_txt_csv(f'{path}/Gyr_y.txt')
      gyr_z = load_txt_csv(f'{path}/Gyr_z.txt')
      mag_x = load_txt_csv(f'{path}/Mag_x.txt')
      mag_y = load_txt_csv(f'{path}/Mag_y.txt')
      mag_z = load_txt_csv(f'{path}/Mag_z.txt')
      data = np.stack([acc_x, acc_y, acc_z, gyr_x, gyr_y, gyr_z, mag_x, mag_y, mag_z], axis=2)
      return data
  
  def _load_from_folder(self):
      '''
      Load all sensors from folder (location)
      '''
      if self.flag == "test":
          filepath = self.datapath
          data = self._load_location_data(filepath)
          return data
      else:
          filepath = os.path.join(self.datapath, self.location)
          labels = self._load_label_file(os.path.join(filepath, "Label.txt"))
          data = self._load_location_data(filepath)
          return data, labels
  def _load_all(self):
      if self.flag == 'test':
          data = self._load_from_folder()
          return data
      self.location = "Hips"
      hips_data, hips_labels = self._load_from_folder()
      self.location = "Bag"
      bag_data, bag_labels = self._load_from_folder()
      self.location = "Hand"
      hand_data, hand_labels = self._load_from_folder()
      self.location = "Torso"
      torso_data, torso_labels = self._load_from_folder()
      data = np.concatenate([hips_data, bag_data, hand_data, torso_data], axis = 0)
      labels = np.concatenate([hips_labels, bag_labels, hand_labels, torso_labels], axis=0)
      return data, labels

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, multiply, concatenate, Activation, Masking, Reshape
from tensorflow.keras.layers import Conv1D, BatchNormalization, GlobalAveragePooling1D, Permute, Dropout
from tensorflow.keras import regularizers

class ModelProvider:
  def __init__(self, seq_len = 500, nfeatures = 9, nclasses = 8):
    '''
    | Initializer model provider
    | Args:
    | seq_len - length of time series analysed
    | nfeatures - number of features of each time point
    | nclasses - number of target classes
    | Example usage:
    | provider = ModelProvider(500, 9, 8)
    | model = provider.get_model()
    '''
    self.seq_len = seq_len
    self.nfeatures = nfeatures
    self.nclasses = nclasses
    self.model = None


  def build_model(self):
    '''
    | Build model for SHL Challenge
    | Reimplementation of a model from https://github.com/titu1994/MLSTM-FCN for newer keras
    '''

    def squeeze_excite_block(input):
      ''' Create a squeeze-excite block
      Args:
          input: input tensor
          filters: number of output filters
          k: width factor

      Returns: a keras tensor
      '''
      filters = input.shape[-1] # channel_axis = -1 for TF

      se = GlobalAveragePooling1D()(input)
      se = Reshape((1, filters))(se)
      se = Dense(filters // 16,  activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
      se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)
      se = multiply([input, se])
      return se

    ip = Input(shape=(self.seq_len, self.nfeatures), dtype=float)
    x = Permute((2, 1))(ip)
    x = Masking()(ip)
    x = LSTM(8)(x)
    x = Dropout(0.4)(x)

    y = Conv1D(128, 8, padding='same', kernel_initializer='he_uniform', data_format='channels_last', kernel_regularizer=regularizers.L2(1e-4))(ip)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = squeeze_excite_block(y)
    y = Dropout(0.4)(y)

    y = Conv1D(256, 5, padding='same', kernel_initializer='he_uniform', data_format='channels_last', kernel_regularizer=regularizers.L2(1e-4))(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = squeeze_excite_block(y)
    y = Dropout(0.4)(y)

    y = Conv1D(128, 3, padding='same', kernel_initializer='he_uniform', data_format='channels_last', kernel_regularizer=regularizers.L2(1e-4))(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = GlobalAveragePooling1D()(y)
    y = Dropout(0.4)(y)

    x = concatenate([x, y])
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.4)(x)
    out = Dense(self.nclasses, activation='softmax')(x)
    self.model = Model(ip, out)

  def from_weights(self, weightpath):
    '''
    Get model from existing weights
    '''
    self.model = self.build_model()
    self.model.load_weights(weightpath)
    return self.model

  def get_model(self):
    if self.model is None:
      self.build_model()
    return self.model

# %%
mprovider = ModelProvider(nfeatures = 9)
#model_path = "/net/tscratch/people/plgjsikora/models/MLSTM_athena__all_vali_vali.weights.h5"
#model = mprovider.from_weights(model_path)
model = mprovider.get_model()
print(model.summary())
# Out:
# 2025-06-16 16:29:18.416184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38668 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c7:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 500, 9)]     0           []
#
#  conv1d (Conv1D)                (None, 500, 128)     9344        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 500, 128)    512         ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 500, 128)     0           ['batch_normalization[0][0]']
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['activation[0][0]']
#  alAveragePooling1D)
#
#  reshape (Reshape)              (None, 1, 128)       0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1, 8)         1024        ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 128)       1024        ['dense[0][0]']
#
#  multiply (Multiply)            (None, 500, 128)     0           ['activation[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 500, 128)     0           ['multiply[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 500, 256)     164096      ['dropout_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 500, 256)    1024        ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 500, 256)     0           ['batch_normalization_1[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 256)         0           ['activation_1[0][0]']
#  obalAveragePooling1D)
#
#  reshape_1 (Reshape)            (None, 1, 256)       0           ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dense_2 (Dense)                (None, 1, 16)        4096        ['reshape_1[0][0]']
#
#  dense_3 (Dense)                (None, 1, 256)       4096        ['dense_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 500, 256)     0           ['activation_1[0][0]',
#                                                                   'dense_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 500, 256)     0           ['multiply_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 500, 128)     98432       ['dropout_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 500, 128)    512         ['conv1d_2[0][0]']
#  rmalization)
#
#  masking (Masking)              (None, 500, 9)       0           ['input_1[0][0]']
#
#  activation_2 (Activation)      (None, 500, 128)     0           ['batch_normalization_2[0][0]']
#
#  lstm (LSTM)                    (None, 8)            576         ['masking[0][0]']
#
#  global_average_pooling1d_2 (Gl  (None, 128)         0           ['activation_2[0][0]']
#  obalAveragePooling1D)
#
#  dropout (Dropout)              (None, 8)            0           ['lstm[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['global_average_pooling1d_2[0][0
#                                                                  ]']
#
#  concatenate (Concatenate)      (None, 136)          0           ['dropout[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  dense_4 (Dense)                (None, 128)          17536       ['concatenate[0][0]']
#
#  dropout_4 (Dropout)            (None, 128)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 8)            1032        ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 303,304
# Trainable params: 302,280
# Non-trainable params: 1,024
# __________________________________________________________________________________________________
# None

# %%
# Load data
dprovider = SHLDataProviderRaw(datapath, "validation", "all", silent=False)
x, y = dprovider.load_data()

#dprovider_val = SHLDataProviderRaw(datapath, "validation", "all", silent=False)
#x_val, y_val = dprovider_val.load_data()
# Out:
# Loading labels from: /net/tscratch/people/plgjsikora/data/validation/Hips/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Acc_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Acc_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Acc_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Gyr_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Gyr_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Gyr_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Mag_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Mag_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Mag_z.txt
# Loading labels from: /net/tscratch/people/plgjsikora/data/validation/Bag/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Acc_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Acc_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Acc_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Gyr_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Gyr_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Gyr_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Mag_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Mag_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Mag_z.txt
# Loading labels from: /net/tscratch/people/plgjsikora/data/validation/Hand/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Acc_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Acc_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Acc_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Gyr_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Gyr_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Gyr_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Mag_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Mag_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Mag_z.txt
# Loading labels from: /net/tscratch/people/plgjsikora/data/validation/Torso/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Acc_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Acc_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Acc_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Gyr_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Gyr_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Gyr_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Mag_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Mag_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Mag_z.txt

# %%
print(x.shape, y.shape)
# Out:
# (115156, 500, 9) (115156, 8)

# %%
# prepare data

x[np.isnan(x)] = 0
x[np.isnan(x)] = 0


#x_n = x
#print(x.T.shape)
#for i in range(len(x.T)):
  #print(np.max(x.T[i]), np.min(x.T[i]))
  #x_n.T[i] = (x.T[i] - np.min(x.T[i])) / (np.max(x.T[i]) - np.min(x.T[i]))
  #print("-----------------------------")
#print(x_n.shape)
#print(np.min(x_n), np.max(x_n))

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 0.2, random_state=10)

# %%
# compile model

from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from datetime import datetime
today = datetime.today().strftime('%Y-%m-%d')

model_checkpoint_path =  f"/net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs{today}.weights.h5"
model_checkpoint = ModelCheckpoint(model_checkpoint_path, verbose=1, mode='auto',
                                       monitor='val_accuracy', save_best_only=True, save_weights_only=True)

optm = Adam(learning_rate=5e-4)

callback_list = [model_checkpoint]
model.compile(optimizer=optm, loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=256, epochs=50, verbose=1, shuffle=True, callbacks=callback_list, validation_freq=1, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 2025-06-16 16:41:44.504370: W tensorflow/core/common_runtime/type_inference.cc:339] Type inference failed. This indicates an invalid graph that escaped type checking. Error message: INVALID_ARGUMENT: expected compatible input types, but input 1:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_INT32
#     }
#   }
# }
#  is neither a subtype nor a supertype of the combined inputs preceding it:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_FLOAT
#     }
#   }
# }
#
# 	while inferring type of node 'cond_40/output/_23'
# 2025-06-16 16:41:45.361574: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8401
# 2025-06-16 16:41:46.365349: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 360/360 [==============================] - ETA: 0s - loss: 1.5201 - accuracy: 0.4791
# Epoch 1: val_accuracy improved from -inf to 0.66507, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 26s 46ms/step - loss: 1.5201 - accuracy: 0.4791 - val_loss: 1.0228 - val_accuracy: 0.6651
# Epoch 2/50
# 359/360 [============================>.] - ETA: 0s - loss: 1.0064 - accuracy: 0.6717
# Epoch 2: val_accuracy improved from 0.66507 to 0.74961, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 1.0063 - accuracy: 0.6717 - val_loss: 0.7877 - val_accuracy: 0.7496
# Epoch 3/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.8154 - accuracy: 0.7415
# Epoch 3: val_accuracy improved from 0.74961 to 0.80115, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.8152 - accuracy: 0.7415 - val_loss: 0.6505 - val_accuracy: 0.8011
# Epoch 4/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.7091 - accuracy: 0.7815
# Epoch 4: val_accuracy improved from 0.80115 to 0.82576, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.7092 - accuracy: 0.7815 - val_loss: 0.5890 - val_accuracy: 0.8258
# Epoch 5/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.6479 - accuracy: 0.8042
# Epoch 5: val_accuracy improved from 0.82576 to 0.83471, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.6477 - accuracy: 0.8042 - val_loss: 0.5657 - val_accuracy: 0.8347
# Epoch 6/50
# 360/360 [==============================] - ETA: 0s - loss: 0.6016 - accuracy: 0.8201
# Epoch 6: val_accuracy improved from 0.83471 to 0.85524, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 41ms/step - loss: 0.6016 - accuracy: 0.8201 - val_loss: 0.5004 - val_accuracy: 0.8552
# Epoch 7/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.5732 - accuracy: 0.8309
# Epoch 7: val_accuracy improved from 0.85524 to 0.86254, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.5733 - accuracy: 0.8308 - val_loss: 0.4817 - val_accuracy: 0.8625
# Epoch 8/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.5496 - accuracy: 0.8375
# Epoch 8: val_accuracy improved from 0.86254 to 0.86697, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.5497 - accuracy: 0.8374 - val_loss: 0.4664 - val_accuracy: 0.8670
# Epoch 9/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.5286 - accuracy: 0.8462
# Epoch 9: val_accuracy improved from 0.86697 to 0.87396, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.5285 - accuracy: 0.8462 - val_loss: 0.4459 - val_accuracy: 0.8740
# Epoch 10/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.5046 - accuracy: 0.8531
# Epoch 10: val_accuracy improved from 0.87396 to 0.87500, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.5043 - accuracy: 0.8532 - val_loss: 0.4425 - val_accuracy: 0.8750
# Epoch 11/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.4897 - accuracy: 0.8590
# Epoch 11: val_accuracy improved from 0.87500 to 0.88338, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.4898 - accuracy: 0.8589 - val_loss: 0.4156 - val_accuracy: 0.8834
# Epoch 12/50
# 360/360 [==============================] - ETA: 0s - loss: 0.4762 - accuracy: 0.8629
# Epoch 12: val_accuracy did not improve from 0.88338
# 360/360 [==============================] - 14s 40ms/step - loss: 0.4762 - accuracy: 0.8629 - val_loss: 0.4217 - val_accuracy: 0.8797
# Epoch 13/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.4633 - accuracy: 0.8674
# Epoch 13: val_accuracy improved from 0.88338 to 0.88499, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.4631 - accuracy: 0.8674 - val_loss: 0.4085 - val_accuracy: 0.8850
# Epoch 14/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.4533 - accuracy: 0.8704
# Epoch 14: val_accuracy improved from 0.88499 to 0.89371, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.4533 - accuracy: 0.8704 - val_loss: 0.3887 - val_accuracy: 0.8937
# Epoch 15/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.4427 - accuracy: 0.8724
# Epoch 15: val_accuracy did not improve from 0.89371
# 360/360 [==============================] - 14s 40ms/step - loss: 0.4427 - accuracy: 0.8723 - val_loss: 0.3899 - val_accuracy: 0.8904
# Epoch 16/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.4304 - accuracy: 0.8776
# Epoch 16: val_accuracy improved from 0.89371 to 0.89649, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 41ms/step - loss: 0.4304 - accuracy: 0.8777 - val_loss: 0.3772 - val_accuracy: 0.8965
# Epoch 17/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.4229 - accuracy: 0.8803
# Epoch 17: val_accuracy did not improve from 0.89649
# 360/360 [==============================] - 14s 40ms/step - loss: 0.4230 - accuracy: 0.8802 - val_loss: 0.3794 - val_accuracy: 0.8946
# Epoch 18/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.4186 - accuracy: 0.8818
# Epoch 18: val_accuracy improved from 0.89649 to 0.89654, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.4187 - accuracy: 0.8818 - val_loss: 0.3744 - val_accuracy: 0.8965
# Epoch 19/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.4080 - accuracy: 0.8834
# Epoch 19: val_accuracy improved from 0.89654 to 0.89927, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.4081 - accuracy: 0.8834 - val_loss: 0.3705 - val_accuracy: 0.8993
# Epoch 20/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.4001 - accuracy: 0.8866
# Epoch 20: val_accuracy improved from 0.89927 to 0.90227, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.4003 - accuracy: 0.8865 - val_loss: 0.3588 - val_accuracy: 0.9023
# Epoch 21/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3928 - accuracy: 0.8888
# Epoch 21: val_accuracy did not improve from 0.90227
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3930 - accuracy: 0.8887 - val_loss: 0.3608 - val_accuracy: 0.9021
# Epoch 22/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3868 - accuracy: 0.8911
# Epoch 22: val_accuracy improved from 0.90227 to 0.90652, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3869 - accuracy: 0.8910 - val_loss: 0.3496 - val_accuracy: 0.9065
# Epoch 23/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3820 - accuracy: 0.8920
# Epoch 23: val_accuracy improved from 0.90652 to 0.90826, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3819 - accuracy: 0.8920 - val_loss: 0.3405 - val_accuracy: 0.9083
# Epoch 24/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3787 - accuracy: 0.8929
# Epoch 24: val_accuracy did not improve from 0.90826
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3789 - accuracy: 0.8928 - val_loss: 0.3538 - val_accuracy: 0.9030
# Epoch 25/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3706 - accuracy: 0.8953
# Epoch 25: val_accuracy improved from 0.90826 to 0.90921, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3708 - accuracy: 0.8952 - val_loss: 0.3303 - val_accuracy: 0.9092
# Epoch 26/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3648 - accuracy: 0.8975
# Epoch 26: val_accuracy improved from 0.90921 to 0.91108, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3648 - accuracy: 0.8975 - val_loss: 0.3326 - val_accuracy: 0.9111
# Epoch 27/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3618 - accuracy: 0.8981
# Epoch 27: val_accuracy did not improve from 0.91108
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3620 - accuracy: 0.8980 - val_loss: 0.3370 - val_accuracy: 0.9090
# Epoch 28/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3598 - accuracy: 0.8985
# Epoch 28: val_accuracy did not improve from 0.91108
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3599 - accuracy: 0.8985 - val_loss: 0.3433 - val_accuracy: 0.9052
# Epoch 29/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3548 - accuracy: 0.9006
# Epoch 29: val_accuracy improved from 0.91108 to 0.91243, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.3546 - accuracy: 0.9007 - val_loss: 0.3287 - val_accuracy: 0.9124
# Epoch 30/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3479 - accuracy: 0.9030
# Epoch 30: val_accuracy did not improve from 0.91243
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3481 - accuracy: 0.9029 - val_loss: 0.3365 - val_accuracy: 0.9082
# Epoch 31/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3488 - accuracy: 0.9025
# Epoch 31: val_accuracy did not improve from 0.91243
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3488 - accuracy: 0.9025 - val_loss: 0.3280 - val_accuracy: 0.9115
# Epoch 32/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3461 - accuracy: 0.9048
# Epoch 32: val_accuracy improved from 0.91243 to 0.91342, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3461 - accuracy: 0.9049 - val_loss: 0.3273 - val_accuracy: 0.9134
# Epoch 33/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3388 - accuracy: 0.9065
# Epoch 33: val_accuracy improved from 0.91342 to 0.91612, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3387 - accuracy: 0.9065 - val_loss: 0.3168 - val_accuracy: 0.9161
# Epoch 34/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3350 - accuracy: 0.9073
# Epoch 34: val_accuracy did not improve from 0.91612
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3349 - accuracy: 0.9074 - val_loss: 0.3227 - val_accuracy: 0.9142
# Epoch 35/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3333 - accuracy: 0.9073
# Epoch 35: val_accuracy improved from 0.91612 to 0.91920, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3333 - accuracy: 0.9074 - val_loss: 0.3048 - val_accuracy: 0.9192
# Epoch 36/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3295 - accuracy: 0.9074
# Epoch 36: val_accuracy did not improve from 0.91920
# 360/360 [==============================] - 15s 40ms/step - loss: 0.3294 - accuracy: 0.9075 - val_loss: 0.3060 - val_accuracy: 0.9188
# Epoch 37/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3255 - accuracy: 0.9103
# Epoch 37: val_accuracy did not improve from 0.91920
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3255 - accuracy: 0.9103 - val_loss: 0.3173 - val_accuracy: 0.9155
# Epoch 38/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3236 - accuracy: 0.9107
# Epoch 38: val_accuracy improved from 0.91920 to 0.92033, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3236 - accuracy: 0.9108 - val_loss: 0.3052 - val_accuracy: 0.9203
# Epoch 39/50
# 360/360 [==============================] - ETA: 0s - loss: 0.3195 - accuracy: 0.9110
# Epoch 39: val_accuracy did not improve from 0.92033
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3195 - accuracy: 0.9110 - val_loss: 0.3118 - val_accuracy: 0.9166
# Epoch 40/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3202 - accuracy: 0.9125
# Epoch 40: val_accuracy did not improve from 0.92033
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3203 - accuracy: 0.9125 - val_loss: 0.3074 - val_accuracy: 0.9182
# Epoch 41/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3174 - accuracy: 0.9131
# Epoch 41: val_accuracy did not improve from 0.92033
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3173 - accuracy: 0.9132 - val_loss: 0.3372 - val_accuracy: 0.9083
# Epoch 42/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3171 - accuracy: 0.9126
# Epoch 42: val_accuracy did not improve from 0.92033
# 360/360 [==============================] - 15s 40ms/step - loss: 0.3171 - accuracy: 0.9126 - val_loss: 0.2984 - val_accuracy: 0.9201
# Epoch 43/50
# 360/360 [==============================] - ETA: 0s - loss: 0.3122 - accuracy: 0.9145
# Epoch 43: val_accuracy did not improve from 0.92033
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3122 - accuracy: 0.9145 - val_loss: 0.3180 - val_accuracy: 0.9178
# Epoch 44/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3151 - accuracy: 0.9138
# Epoch 44: val_accuracy improved from 0.92033 to 0.92107, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.3152 - accuracy: 0.9138 - val_loss: 0.2983 - val_accuracy: 0.9211
# Epoch 45/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3085 - accuracy: 0.9152
# Epoch 45: val_accuracy improved from 0.92107 to 0.92115, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.3083 - accuracy: 0.9152 - val_loss: 0.2964 - val_accuracy: 0.9212
# Epoch 46/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3030 - accuracy: 0.9171
# Epoch 46: val_accuracy did not improve from 0.92115
# 360/360 [==============================] - 15s 40ms/step - loss: 0.3029 - accuracy: 0.9172 - val_loss: 0.3003 - val_accuracy: 0.9199
# Epoch 47/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3029 - accuracy: 0.9172
# Epoch 47: val_accuracy did not improve from 0.92115
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3030 - accuracy: 0.9171 - val_loss: 0.3255 - val_accuracy: 0.9121
# Epoch 48/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3011 - accuracy: 0.9179
# Epoch 48: val_accuracy improved from 0.92115 to 0.92285, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3010 - accuracy: 0.9179 - val_loss: 0.2952 - val_accuracy: 0.9228
# Epoch 49/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.3004 - accuracy: 0.9178
# Epoch 49: val_accuracy improved from 0.92285 to 0.92389, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.3006 - accuracy: 0.9177 - val_loss: 0.2893 - val_accuracy: 0.9239
# Epoch 50/50
# 359/360 [============================>.] - ETA: 0s - loss: 0.2968 - accuracy: 0.9185
# Epoch 50: val_accuracy did not improve from 0.92389
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2968 - accuracy: 0.9185 - val_loss: 0.2935 - val_accuracy: 0.9233

# %%
import pickle
with open(f'/net/tscratch/people/plgjsikora/hist{today}.pickle', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
# confusion matrix and model statistics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_pred = model.predict(x_val, batch_size=256)


np.save("/net/tscratch/people/plgjsikora/preds.npy", y_pred)
np.save("/net/tscratch/people/plgjsikora/vals.npy", y_val)
# Out:
# 90/90 [==============================] - 1s 12ms/step

# %%
#import matplotlib.pyplot as plt
#disp.plot()
#plt.show()
#plt.savefig(f"/net/tscratch/people/plgjsikora/cm{today}_valitovali_50epochs.png")

# %%
from sklearn.metrics import classification_report

cr = classification_report(y_val_a, y_pred_a)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.89      0.96      0.92      4669
#            2       0.94      0.93      0.93      4207
#            3       1.00      0.96      0.98       440
#            4       0.93      0.95      0.94      1916
#            5       0.97      0.96      0.97      3322
#            6       0.91      0.93      0.92      1510
#            7       0.89      0.89      0.89      3523
#            8       0.94      0.85      0.89      3445
#
#     accuracy                           0.92     23032
#    macro avg       0.93      0.93      0.93     23032
# weighted avg       0.92      0.92      0.92     23032

# %%
with open(f'/net/tscratch/people/plgjsikora/classification_report{today}.pickle', 'wb') as file_pi:
    pickle.dump(cr, file_pi)

# %%
# reduce lr and train more
optm = Adam(learning_rate=1e-4)

callback_list = [model_checkpoint]
model.compile(optimizer=optm, loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=256, epochs=150, verbose=1, shuffle=True, callbacks=callback_list, validation_freq=1, validation_data=(x_val, y_val))
# Out:
# Epoch 1/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2613 - accuracy: 0.9309
# Epoch 1: val_accuracy improved from 0.92389 to 0.93027, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 21s 45ms/step - loss: 0.2615 - accuracy: 0.9308 - val_loss: 0.2685 - val_accuracy: 0.9303
# Epoch 2/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2541 - accuracy: 0.9335
# Epoch 2: val_accuracy improved from 0.93027 to 0.93123, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 41ms/step - loss: 0.2539 - accuracy: 0.9336 - val_loss: 0.2715 - val_accuracy: 0.9312
# Epoch 3/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2502 - accuracy: 0.9345
# Epoch 3: val_accuracy improved from 0.93123 to 0.93235, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 41ms/step - loss: 0.2502 - accuracy: 0.9345 - val_loss: 0.2666 - val_accuracy: 0.9324
# Epoch 4/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2457 - accuracy: 0.9360
# Epoch 4: val_accuracy did not improve from 0.93235
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2458 - accuracy: 0.9360 - val_loss: 0.2677 - val_accuracy: 0.9319
# Epoch 5/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2454 - accuracy: 0.9357
# Epoch 5: val_accuracy did not improve from 0.93235
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2455 - accuracy: 0.9357 - val_loss: 0.2692 - val_accuracy: 0.9311
# Epoch 6/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2444 - accuracy: 0.9355
# Epoch 6: val_accuracy improved from 0.93235 to 0.93292, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2443 - accuracy: 0.9355 - val_loss: 0.2651 - val_accuracy: 0.9329
# Epoch 7/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2426 - accuracy: 0.9372
# Epoch 7: val_accuracy improved from 0.93292 to 0.93366, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 41ms/step - loss: 0.2425 - accuracy: 0.9372 - val_loss: 0.2643 - val_accuracy: 0.9337
# Epoch 8/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2422 - accuracy: 0.9372
# Epoch 8: val_accuracy improved from 0.93366 to 0.93379, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2421 - accuracy: 0.9372 - val_loss: 0.2591 - val_accuracy: 0.9338
# Epoch 9/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2382 - accuracy: 0.9374
# Epoch 9: val_accuracy did not improve from 0.93379
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2382 - accuracy: 0.9374 - val_loss: 0.2604 - val_accuracy: 0.9337
# Epoch 10/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2356 - accuracy: 0.9382
# Epoch 10: val_accuracy improved from 0.93379 to 0.93427, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2355 - accuracy: 0.9383 - val_loss: 0.2619 - val_accuracy: 0.9343
# Epoch 11/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2357 - accuracy: 0.9377
# Epoch 11: val_accuracy improved from 0.93427 to 0.93466, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2357 - accuracy: 0.9377 - val_loss: 0.2589 - val_accuracy: 0.9347
# Epoch 12/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2326 - accuracy: 0.9393
# Epoch 12: val_accuracy improved from 0.93466 to 0.93492, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2326 - accuracy: 0.9392 - val_loss: 0.2600 - val_accuracy: 0.9349
# Epoch 13/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2336 - accuracy: 0.9379
# Epoch 13: val_accuracy did not improve from 0.93492
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2336 - accuracy: 0.9380 - val_loss: 0.2581 - val_accuracy: 0.9347
# Epoch 14/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2335 - accuracy: 0.9389
# Epoch 14: val_accuracy improved from 0.93492 to 0.93531, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2336 - accuracy: 0.9388 - val_loss: 0.2562 - val_accuracy: 0.9353
# Epoch 15/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2304 - accuracy: 0.9400
# Epoch 15: val_accuracy improved from 0.93531 to 0.93600, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2305 - accuracy: 0.9399 - val_loss: 0.2551 - val_accuracy: 0.9360
# Epoch 16/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2293 - accuracy: 0.9397
# Epoch 16: val_accuracy did not improve from 0.93600
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2293 - accuracy: 0.9397 - val_loss: 0.2591 - val_accuracy: 0.9344
# Epoch 17/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2303 - accuracy: 0.9392
# Epoch 17: val_accuracy did not improve from 0.93600
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2302 - accuracy: 0.9392 - val_loss: 0.2595 - val_accuracy: 0.9348
# Epoch 18/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2294 - accuracy: 0.9394
# Epoch 18: val_accuracy did not improve from 0.93600
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2295 - accuracy: 0.9393 - val_loss: 0.2595 - val_accuracy: 0.9341
# Epoch 19/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2285 - accuracy: 0.9394
# Epoch 19: val_accuracy did not improve from 0.93600
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2284 - accuracy: 0.9394 - val_loss: 0.2577 - val_accuracy: 0.9360
# Epoch 20/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2271 - accuracy: 0.9401
# Epoch 20: val_accuracy did not improve from 0.93600
# 360/360 [==============================] - 15s 41ms/step - loss: 0.2272 - accuracy: 0.9401 - val_loss: 0.2574 - val_accuracy: 0.9347
# Epoch 21/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2256 - accuracy: 0.9404
# Epoch 21: val_accuracy did not improve from 0.93600
# 360/360 [==============================] - 15s 41ms/step - loss: 0.2255 - accuracy: 0.9404 - val_loss: 0.2606 - val_accuracy: 0.9337
# Epoch 22/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2248 - accuracy: 0.9407
# Epoch 22: val_accuracy did not improve from 0.93600
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2249 - accuracy: 0.9407 - val_loss: 0.2530 - val_accuracy: 0.9348
# Epoch 23/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2217 - accuracy: 0.9414
# Epoch 23: val_accuracy improved from 0.93600 to 0.93635, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2217 - accuracy: 0.9414 - val_loss: 0.2500 - val_accuracy: 0.9363
# Epoch 24/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2222 - accuracy: 0.9410
# Epoch 24: val_accuracy did not improve from 0.93635
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2221 - accuracy: 0.9410 - val_loss: 0.2549 - val_accuracy: 0.9360
# Epoch 25/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2245 - accuracy: 0.9400
# Epoch 25: val_accuracy did not improve from 0.93635
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2246 - accuracy: 0.9400 - val_loss: 0.2544 - val_accuracy: 0.9350
# Epoch 26/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2207 - accuracy: 0.9412
# Epoch 26: val_accuracy did not improve from 0.93635
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2209 - accuracy: 0.9411 - val_loss: 0.2560 - val_accuracy: 0.9344
# Epoch 27/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2206 - accuracy: 0.9414
# Epoch 27: val_accuracy did not improve from 0.93635
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2205 - accuracy: 0.9414 - val_loss: 0.2550 - val_accuracy: 0.9341
# Epoch 28/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2195 - accuracy: 0.9418
# Epoch 28: val_accuracy did not improve from 0.93635
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2197 - accuracy: 0.9417 - val_loss: 0.2576 - val_accuracy: 0.9339
# Epoch 29/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2194 - accuracy: 0.9414
# Epoch 29: val_accuracy did not improve from 0.93635
# 360/360 [==============================] - 15s 41ms/step - loss: 0.2196 - accuracy: 0.9413 - val_loss: 0.2559 - val_accuracy: 0.9354
# Epoch 30/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2189 - accuracy: 0.9422
# Epoch 30: val_accuracy improved from 0.93635 to 0.93743, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2190 - accuracy: 0.9422 - val_loss: 0.2485 - val_accuracy: 0.9374
# Epoch 31/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2164 - accuracy: 0.9425
# Epoch 31: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2163 - accuracy: 0.9425 - val_loss: 0.2472 - val_accuracy: 0.9368
# Epoch 32/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2187 - accuracy: 0.9418
# Epoch 32: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2188 - accuracy: 0.9418 - val_loss: 0.2553 - val_accuracy: 0.9341
# Epoch 33/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2164 - accuracy: 0.9418
# Epoch 33: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2164 - accuracy: 0.9418 - val_loss: 0.2517 - val_accuracy: 0.9365
# Epoch 34/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2155 - accuracy: 0.9428
# Epoch 34: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2156 - accuracy: 0.9428 - val_loss: 0.2558 - val_accuracy: 0.9344
# Epoch 35/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2143 - accuracy: 0.9431
# Epoch 35: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2142 - accuracy: 0.9431 - val_loss: 0.2500 - val_accuracy: 0.9368
# Epoch 36/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2149 - accuracy: 0.9422
# Epoch 36: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2149 - accuracy: 0.9423 - val_loss: 0.2456 - val_accuracy: 0.9369
# Epoch 37/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2162 - accuracy: 0.9424
# Epoch 37: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2161 - accuracy: 0.9424 - val_loss: 0.2473 - val_accuracy: 0.9372
# Epoch 38/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2158 - accuracy: 0.9419
# Epoch 38: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2158 - accuracy: 0.9419 - val_loss: 0.2530 - val_accuracy: 0.9358
# Epoch 39/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2136 - accuracy: 0.9425
# Epoch 39: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2136 - accuracy: 0.9426 - val_loss: 0.2506 - val_accuracy: 0.9357
# Epoch 40/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2128 - accuracy: 0.9430
# Epoch 40: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 41ms/step - loss: 0.2127 - accuracy: 0.9430 - val_loss: 0.2503 - val_accuracy: 0.9354
# Epoch 41/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2117 - accuracy: 0.9441
# Epoch 41: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2118 - accuracy: 0.9441 - val_loss: 0.2515 - val_accuracy: 0.9354
# Epoch 42/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2118 - accuracy: 0.9441
# Epoch 42: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2117 - accuracy: 0.9442 - val_loss: 0.2518 - val_accuracy: 0.9345
# Epoch 43/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2081 - accuracy: 0.9440
# Epoch 43: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2082 - accuracy: 0.9439 - val_loss: 0.2521 - val_accuracy: 0.9351
# Epoch 44/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2102 - accuracy: 0.9438
# Epoch 44: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2102 - accuracy: 0.9438 - val_loss: 0.2464 - val_accuracy: 0.9372
# Epoch 45/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2084 - accuracy: 0.9436
# Epoch 45: val_accuracy did not improve from 0.93743
# 360/360 [==============================] - 14s 40ms/step - loss: 0.2084 - accuracy: 0.9436 - val_loss: 0.2506 - val_accuracy: 0.9356
# Epoch 46/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2102 - accuracy: 0.9435
# Epoch 46: val_accuracy improved from 0.93743 to 0.93861, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_valitovali_alllocs2025-06-16.weights.h5
# 360/360 [==============================] - 15s 41ms/step - loss: 0.2104 - accuracy: 0.9434 - val_loss: 0.2439 - val_accuracy: 0.9386
# Epoch 47/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2059 - accuracy: 0.9450
# Epoch 47: val_accuracy did not improve from 0.93861
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2059 - accuracy: 0.9450 - val_loss: 0.2457 - val_accuracy: 0.9369
# Epoch 48/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2085 - accuracy: 0.9437
# Epoch 48: val_accuracy did not improve from 0.93861
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2085 - accuracy: 0.9436 - val_loss: 0.2479 - val_accuracy: 0.9360
# Epoch 49/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2067 - accuracy: 0.9443
# Epoch 49: val_accuracy did not improve from 0.93861
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2066 - accuracy: 0.9443 - val_loss: 0.2474 - val_accuracy: 0.9360
# Epoch 50/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2082 - accuracy: 0.9445
# Epoch 50: val_accuracy did not improve from 0.93861
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2080 - accuracy: 0.9446 - val_loss: 0.2477 - val_accuracy: 0.9364
# Epoch 51/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2075 - accuracy: 0.9446
# Epoch 51: val_accuracy did not improve from 0.93861
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2075 - accuracy: 0.9447 - val_loss: 0.2427 - val_accuracy: 0.9375
# Epoch 52/150
# 359/360 [============================>.] - ETA: 0s - loss: 0.2062 - accuracy: 0.9448
# Epoch 52: val_accuracy did not improve from 0.93861
# 360/360 [==============================] - 15s 40ms/step - loss: 0.2061 - accuracy: 0.9449 - val_loss: 0.2501 - val_accuracy: 0.9351
# Epoch 53/150
# 221/360 [=================>............] - ETA: 5s - loss: 0.2083 - accuracy: 0.9437
