# %%
import os
datapath = "/net/tscratch/people/plgjsikora/data"

# %%
import numpy as np
import pandas as pd
from keras.utils import to_categorical

class SHLDataProviderRaw:
  def __init__(self, root_path:str, flag: str, mode: str, location: str = "Hips", sensor: str = "Acc_x", silent = True, four_locs = False, randomlyzero = True):
    '''
    | Setup data provider for SHL 2025 Challenge
    | Args:
    | root_path: path to root data folder
    | flag: one of train, validation, test
    | mode: one of singlefile, singlefolder, all
    | location: where to load from (Hips/Bag etc)
    | sensor: which file to load (Acc_x/Mag_z etc)
    | silent: supress print statements
    | randomlyzero: randomly zero out some sensor in train dataset
    | Example usage:
    | provider = SHLDataProviderRaw(datapath, "train", "singlefolder", location="Bag")
    | x, y = provider.load_data()
    '''
    self.mode = mode.lower()
    self.flag = flag.lower()
    self.location = location.capitalize()
    self.sensor = sensor.capitalize()
    self.silent = silent
    if self.flag not in ["test", "train", "validation"]:
      raise ValueError(f"Unexpected flag received: got {self.flag}")
    if self.flag == 'train' and randomlyzero:
        self.zero = True
    else:
        self.zero = False
    if self.mode not in ["singlefile", "singlefolder", "all"]:
      raise ValueError(f"Unexpected mode received: got {self.mode}")
    if self.flag == 'train' and four_locs:
      self.datapath = os.path.join(root_path, "train_4_locations")
    else:
      self.datapath = os.path.join(root_path, self.flag)

  def load_data(self):
    if self.mode == "singlefile":
      x_data, y_data = self._load_from_file()
    elif self.mode == "singlefolder":
      x_data, y_data = self._load_from_folder()
    elif self.mode == "all":
      x_data, y_data = self._load_all()
    return np.array(x_data), np.array(y_data)

  def _load_label_file(self, labelpath):
      if not self.silent:
        print(f"Loading labels from: {labelpath}")
      y_data = np.loadtxt(labelpath, dtype=int)
      y_data[np.isnan(y_data)] = 1
      y_data = np.median(y_data, axis=1).astype(int)
      y_data = y_data - 1
      y_data = to_categorical(y_data, len(np.unique(y_data)))
      return y_data

  def _load_location_data(self, path):
      def load_txt_csv(path):
            if not self.silent:
                print(f"Loading data from: {path}")
            if self.flag == 'test':
                np_data = np.loadtxt(path, dtype=np.float32, delimiter=",")
            else:
                df = pd.read_csv(path, header=None, delim_whitespace=True, engine='python')
                np_data = df.to_numpy()
                if self.zero: # randomly zero out 5% of sensors
                    size = np_data.shape[0]
                    print(size)
                    zeroindices = np.random.choice(size, int(size*0.05), replace=False)
                    zeroindices[zeroindices >= size] == size - 1
                    np_data[zeroindices] = np.zeros((500,))              
            return np_data
      acc_x = load_txt_csv(f'{path}/Acc_x.txt')
      acc_y = load_txt_csv(f'{path}/Acc_y.txt')
      acc_z = load_txt_csv(f'{path}/Acc_z.txt')
      gyr_x = load_txt_csv(f'{path}/Gyr_x.txt')
      gyr_y = load_txt_csv(f'{path}/Gyr_y.txt')
      gyr_z = load_txt_csv(f'{path}/Gyr_z.txt')
      mag_x = load_txt_csv(f'{path}/Mag_x.txt')
      mag_y = load_txt_csv(f'{path}/Mag_y.txt')
      mag_z = load_txt_csv(f'{path}/Mag_z.txt')
      data = np.stack([acc_x, acc_y, acc_z, gyr_x, gyr_y, gyr_z, mag_x, mag_y, mag_z], axis=2)
      return data
  
  def _load_from_folder(self):
      '''
      Load all sensors from folder (location)
      '''
      if self.flag == "test":
          filepath = self.datapath
          data = self._load_location_data(filepath)
          return data
      else:
          filepath = os.path.join(self.datapath, self.location)
          labels = self._load_label_file(os.path.join(filepath, "Label.txt"))
          data = self._load_location_data(filepath)
          return data, labels
  def _load_all(self):
      if self.flag == 'test':
          data = self._load_from_folder()
          return data
      self.location = "Hips"
      hips_data, hips_labels = self._load_from_folder()
      self.location = "Bag"
      bag_data, bag_labels = self._load_from_folder()
      self.location = "Hand"
      hand_data, hand_labels = self._load_from_folder()
      self.location = "Torso"
      torso_data, torso_labels = self._load_from_folder()
      data = np.concatenate([hips_data, bag_data, hand_data, torso_data], axis = 0)
      labels = np.concatenate([hips_labels, bag_labels, hand_labels, torso_labels], axis=0)
      return data, labels

# %%
dprovider = SHLDataProviderRaw(datapath, "train", "all", silent=False)
x_train, y_train = dprovider.load_data()
dprovidervali = SHLDataProviderRaw(datapath, "validation", "all", silent=False)
x_val, y_val = dprovidervali.load_data()
# Out:
# Loading labels from: /net/tscratch/people/plgjsikora/data/train/Hips/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hips/Acc_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hips/Acc_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hips/Acc_z.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hips/Gyr_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hips/Gyr_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hips/Gyr_z.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hips/Mag_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hips/Mag_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hips/Mag_z.txt
# 196072
# Loading labels from: /net/tscratch/people/plgjsikora/data/train/Bag/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Bag/Acc_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Bag/Acc_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Bag/Acc_z.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Bag/Gyr_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Bag/Gyr_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Bag/Gyr_z.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Bag/Mag_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Bag/Mag_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Bag/Mag_z.txt
# 196072
# Loading labels from: /net/tscratch/people/plgjsikora/data/train/Hand/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hand/Acc_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hand/Acc_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hand/Acc_z.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hand/Gyr_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hand/Gyr_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hand/Gyr_z.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hand/Mag_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hand/Mag_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Hand/Mag_z.txt
# 196072
# Loading labels from: /net/tscratch/people/plgjsikora/data/train/Torso/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Torso/Acc_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Torso/Acc_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Torso/Acc_z.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Torso/Gyr_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Torso/Gyr_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Torso/Gyr_z.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Torso/Mag_x.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Torso/Mag_y.txt
# 196072
# Loading data from: /net/tscratch/people/plgjsikora/data/train/Torso/Mag_z.txt
# 196072
# Loading labels from: /net/tscratch/people/plgjsikora/data/validation/Hips/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Acc_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Acc_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Acc_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Gyr_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Gyr_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Gyr_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Mag_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Mag_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hips/Mag_z.txt
# Loading labels from: /net/tscratch/people/plgjsikora/data/validation/Bag/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Acc_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Acc_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Acc_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Gyr_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Gyr_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Gyr_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Mag_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Mag_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Bag/Mag_z.txt
# Loading labels from: /net/tscratch/people/plgjsikora/data/validation/Hand/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Acc_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Acc_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Acc_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Gyr_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Gyr_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Gyr_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Mag_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Mag_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Hand/Mag_z.txt
# Loading labels from: /net/tscratch/people/plgjsikora/data/validation/Torso/Label.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Acc_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Acc_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Acc_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Gyr_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Gyr_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Gyr_z.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Mag_x.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Mag_y.txt
# Loading data from: /net/tscratch/people/plgjsikora/data/validation/Torso/Mag_z.txt

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, multiply, concatenate, Activation, Masking, Reshape
from tensorflow.keras.layers import Conv1D, BatchNormalization, GlobalAveragePooling1D, Permute, Dropout
from tensorflow.keras import regularizers
class ModelProviderNoAntiOverfitting:
  def __init__(self, seq_len = 500, nfeatures = 9, nclasses = 8):
    '''
    | Initializer model provider
    | Args:
    | seq_len - length of time series analysed
    | nfeatures - number of features of each time point
    | nclasses - number of target classes
    | Example usage:
    | provider = ModelProvider(500, 9, 8)
    | model = provider.get_model()
    '''
    self.seq_len = seq_len
    self.nfeatures = nfeatures
    self.nclasses = nclasses
    self.model = None


  def build_model(self):
    '''
    | Build model for SHL Challenge
    | Reimplementation of a model from https://github.com/titu1994/MLSTM-FCN for newer keras
    '''

    def squeeze_excite_block(input):
      ''' Create a squeeze-excite block
      Args:
          input: input tensor
          filters: number of output filters
          k: width factor

      Returns: a keras tensor
      '''
      filters = input.shape[-1] # channel_axis = -1 for TF

      se = GlobalAveragePooling1D()(input)
      se = Reshape((1, filters))(se)
      se = Dense(filters // 16,  activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
      se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)
      se = multiply([input, se])
      return se

    ip = Input(shape=(self.seq_len, self.nfeatures), dtype=float)
    x = Permute((2, 1))(ip)
    x = Masking()(ip)
    x = LSTM(8)(x)

    y = Conv1D(128, 8, padding='same', kernel_initializer='he_uniform', data_format='channels_last')(ip)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = squeeze_excite_block(y)

    y = Conv1D(256, 5, padding='same', kernel_initializer='he_uniform', data_format='channels_last')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = squeeze_excite_block(y)

    y = Conv1D(128, 3, padding='same', kernel_initializer='he_uniform', data_format='channels_last')(y)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)
    y = GlobalAveragePooling1D()(y)

    x = concatenate([x, y])
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.4)(x)
    out = Dense(self.nclasses, activation='softmax')(x)
    self.model = Model(ip, out)

  def from_weights(self, weightpath):
    '''
    Get model from existing weights
    '''
    self.build_model()
    self.model.load_weights(weightpath)
    return self.model

  def get_model(self):
    if self.model is None:
      self.build_model()
    return self.model

# %%
x_train[np.isnan(x_train)] = 0
x_val[np.isnan(x_val)] = 0

# %%
noantiover = ModelProviderNoAntiOverfitting(nfeatures=9)
nao_model = noantiover.get_model()
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from datetime import datetime
today = datetime.today().strftime('%Y-%m-%d')
nao_model_checkpoint_path =  f"/net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_{today}.weights.h5"
nao_model_checkpoint = ModelCheckpoint(nao_model_checkpoint_path, verbose=1, mode='auto',
                                       monitor='val_accuracy', save_best_only=True, save_weights_only=True)

optm = Adam(learning_rate=5e-4)

callback_list = [nao_model_checkpoint]
nao_model.compile(optimizer=optm, loss='categorical_crossentropy',  metrics=['accuracy'])

# %%
nao_history = nao_model.fit(x_train, y_train, batch_size=256, epochs=50, verbose=1, shuffle=True, callbacks=callback_list, validation_freq=1, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 3064/3064 [==============================] - ETA: 0s - loss: 1.0885 - accuracy: 0.5810
# Epoch 1: val_accuracy improved from -inf to 0.40058, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 126s 39ms/step - loss: 1.0885 - accuracy: 0.5810 - val_loss: 1.7223 - val_accuracy: 0.4006
# Epoch 2/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.7809 - accuracy: 0.7002
# Epoch 2: val_accuracy improved from 0.40058 to 0.42938, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 116s 38ms/step - loss: 0.7809 - accuracy: 0.7002 - val_loss: 1.5551 - val_accuracy: 0.4294
# Epoch 3/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.7002 - accuracy: 0.7320
# Epoch 3: val_accuracy improved from 0.42938 to 0.47821, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 116s 38ms/step - loss: 0.7002 - accuracy: 0.7320 - val_loss: 1.4544 - val_accuracy: 0.4782
# Epoch 4/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.6554 - accuracy: 0.7501
# Epoch 4: val_accuracy improved from 0.47821 to 0.50676, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 116s 38ms/step - loss: 0.6554 - accuracy: 0.7501 - val_loss: 1.4061 - val_accuracy: 0.5068
# Epoch 5/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.6218 - accuracy: 0.7632
# Epoch 5: val_accuracy did not improve from 0.50676
# 3064/3064 [==============================] - 116s 38ms/step - loss: 0.6218 - accuracy: 0.7633 - val_loss: 1.5217 - val_accuracy: 0.4797
# Epoch 6/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.5968 - accuracy: 0.7735
# Epoch 6: val_accuracy did not improve from 0.50676
# 3064/3064 [==============================] - 115s 38ms/step - loss: 0.5968 - accuracy: 0.7735 - val_loss: 1.4859 - val_accuracy: 0.4780
# Epoch 7/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.5780 - accuracy: 0.7814
# Epoch 7: val_accuracy did not improve from 0.50676
# 3064/3064 [==============================] - 115s 38ms/step - loss: 0.5780 - accuracy: 0.7814 - val_loss: 1.4793 - val_accuracy: 0.4772
# Epoch 8/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.5594 - accuracy: 0.7887
# Epoch 8: val_accuracy did not improve from 0.50676
# 3064/3064 [==============================] - 115s 38ms/step - loss: 0.5594 - accuracy: 0.7887 - val_loss: 1.5086 - val_accuracy: 0.4892
# Epoch 9/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.5470 - accuracy: 0.7939
# Epoch 9: val_accuracy did not improve from 0.50676
# 3064/3064 [==============================] - 115s 38ms/step - loss: 0.5470 - accuracy: 0.7939 - val_loss: 1.7093 - val_accuracy: 0.4451
# Epoch 10/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.5347 - accuracy: 0.7987
# Epoch 10: val_accuracy did not improve from 0.50676
# 3064/3064 [==============================] - 115s 38ms/step - loss: 0.5347 - accuracy: 0.7987 - val_loss: 1.7382 - val_accuracy: 0.4550
# Epoch 11/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.5232 - accuracy: 0.8035
# Epoch 11: val_accuracy improved from 0.50676 to 0.51026, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 115s 38ms/step - loss: 0.5233 - accuracy: 0.8035 - val_loss: 1.5328 - val_accuracy: 0.5103
# Epoch 12/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.5137 - accuracy: 0.8075
# Epoch 12: val_accuracy did not improve from 0.51026
# 3064/3064 [==============================] - 116s 38ms/step - loss: 0.5137 - accuracy: 0.8075 - val_loss: 1.5245 - val_accuracy: 0.4806
# Epoch 13/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.5043 - accuracy: 0.8110
# Epoch 13: val_accuracy did not improve from 0.51026
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.5043 - accuracy: 0.8110 - val_loss: 1.5496 - val_accuracy: 0.5025
# Epoch 14/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4945 - accuracy: 0.8147
# Epoch 14: val_accuracy did not improve from 0.51026
# 3064/3064 [==============================] - 116s 38ms/step - loss: 0.4944 - accuracy: 0.8147 - val_loss: 1.5054 - val_accuracy: 0.4987
# Epoch 15/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4884 - accuracy: 0.8172
# Epoch 15: val_accuracy did not improve from 0.51026
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4884 - accuracy: 0.8172 - val_loss: 1.5880 - val_accuracy: 0.4792
# Epoch 16/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4828 - accuracy: 0.8196
# Epoch 16: val_accuracy did not improve from 0.51026
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4828 - accuracy: 0.8196 - val_loss: 1.5320 - val_accuracy: 0.5048
# Epoch 17/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4736 - accuracy: 0.8231
# Epoch 17: val_accuracy did not improve from 0.51026
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4736 - accuracy: 0.8231 - val_loss: 1.5163 - val_accuracy: 0.5065
# Epoch 18/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4673 - accuracy: 0.8259
# Epoch 18: val_accuracy improved from 0.51026 to 0.53388, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4673 - accuracy: 0.8259 - val_loss: 1.4258 - val_accuracy: 0.5339
# Epoch 19/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4603 - accuracy: 0.8287
# Epoch 19: val_accuracy improved from 0.53388 to 0.54384, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4603 - accuracy: 0.8287 - val_loss: 1.4830 - val_accuracy: 0.5438
# Epoch 20/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4556 - accuracy: 0.8302
# Epoch 20: val_accuracy did not improve from 0.54384
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4556 - accuracy: 0.8302 - val_loss: 1.4870 - val_accuracy: 0.5262
# Epoch 21/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4482 - accuracy: 0.8329
# Epoch 21: val_accuracy did not improve from 0.54384
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4482 - accuracy: 0.8329 - val_loss: 1.4701 - val_accuracy: 0.5372
# Epoch 22/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4402 - accuracy: 0.8361
# Epoch 22: val_accuracy did not improve from 0.54384
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4402 - accuracy: 0.8361 - val_loss: 1.5133 - val_accuracy: 0.5339
# Epoch 23/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4337 - accuracy: 0.8389
# Epoch 23: val_accuracy improved from 0.54384 to 0.54659, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4337 - accuracy: 0.8389 - val_loss: 1.4555 - val_accuracy: 0.5466
# Epoch 24/50
# 3064/3064 [==============================] - ETA: 0s - loss: 0.4240 - accuracy: 0.8426
# Epoch 24: val_accuracy improved from 0.54659 to 0.56269, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4240 - accuracy: 0.8426 - val_loss: 1.4234 - val_accuracy: 0.5627
# Epoch 25/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4162 - accuracy: 0.8459
# Epoch 25: val_accuracy did not improve from 0.56269
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4162 - accuracy: 0.8459 - val_loss: 1.4239 - val_accuracy: 0.5600
# Epoch 26/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4110 - accuracy: 0.8473
# Epoch 26: val_accuracy did not improve from 0.56269
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4110 - accuracy: 0.8473 - val_loss: 1.5227 - val_accuracy: 0.5545
# Epoch 27/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4055 - accuracy: 0.8497
# Epoch 27: val_accuracy did not improve from 0.56269
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4055 - accuracy: 0.8497 - val_loss: 1.4554 - val_accuracy: 0.5484
# Epoch 28/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.4020 - accuracy: 0.8508
# Epoch 28: val_accuracy did not improve from 0.56269
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.4019 - accuracy: 0.8508 - val_loss: 1.5486 - val_accuracy: 0.5567
# Epoch 29/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.3963 - accuracy: 0.8529
# Epoch 29: val_accuracy did not improve from 0.56269
# 3064/3064 [==============================] - 117s 38ms/step - loss: 0.3962 - accuracy: 0.8529 - val_loss: 1.4624 - val_accuracy: 0.5593
# Epoch 30/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.3912 - accuracy: 0.8548
# Epoch 30: val_accuracy improved from 0.56269 to 0.56863, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 115s 38ms/step - loss: 0.3913 - accuracy: 0.8548 - val_loss: 1.4433 - val_accuracy: 0.5686
# Epoch 31/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.3878 - accuracy: 0.8563
# Epoch 31: val_accuracy did not improve from 0.56863
# 3064/3064 [==============================] - 115s 37ms/step - loss: 0.3878 - accuracy: 0.8563 - val_loss: 1.3722 - val_accuracy: 0.5664
# Epoch 32/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.3842 - accuracy: 0.8578
# Epoch 32: val_accuracy improved from 0.56863 to 0.58530, saving model to /net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5
# 3064/3064 [==============================] - 115s 38ms/step - loss: 0.3842 - accuracy: 0.8578 - val_loss: 1.4040 - val_accuracy: 0.5853
# Epoch 33/50
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.3812 - accuracy: 0.8587
# Epoch 33: val_accuracy did not improve from 0.58530
# 3064/3064 [==============================] - 116s 38ms/step - loss: 0.3812 - accuracy: 0.8587 - val_loss: 1.3789 - val_accuracy: 0.5842
# Epoch 34/50
#  179/3064 [>.............................] - ETA: 1:42 - loss: 0.3711 - accuracy: 0.8628
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 nao_history = nao_model.fit(x_train, y_train, batch_size=256, epochs=50, verbose=1, shuffle=True, callbacks=callback_list, validation_freq=1, validation_data=(x_val, y_val))
#
# File /net/software/v1/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /net/software/v1/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/keras/engine/training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File /net/software/v1/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /net/software/v1/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File /net/software/v1/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File /net/software/v1/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /net/software/v1/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File /net/software/v1/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File /net/software/v1/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
nao_bestmodelprovider = ModelProviderNoAntiOverfitting(nfeatures = 9)

nao_bestmodel = nao_bestmodelprovider.from_weights(f"/net/tscratch/people/plgjsikora/models/MLSTM_athena_traintovali_alllocs_noantiover_withzeroes_2025-06-17.weights.h5")
y_pred = nao_bestmodel.predict(x_val, batch_size=256)


np.save("/net/tscratch/people/plgjsikora/naopreds50epochs_fromtrain.npy", y_pred)
np.save("/net/tscratch/people/plgjsikora/naovals50epochs_fromtrain.npy", y_val)
# Out:
# 450/450 [==============================] - 6s 11ms/step

# %%
with open(f'/net/tscratch/people/plgjsikora/naohist150epochs_{today}.pickle', 'wb') as file_pi:
    pickle.dump(nao_history.history, file_pi)

# %%
optm = Adam(learning_rate=5e-5)

callback_list = [nao_model_checkpoint]
nao_bestmodel.compile(optimizer=optm, loss='categorical_crossentropy',  metrics=['accuracy'])
hist200 = nao_bestmodel.fit(x_train, y_train, batch_size=256, epochs=200, verbose=1, shuffle=True, callbacks=callback_list, validation_freq=1, validation_data=(x_val, y_val))
# Out:
# Epoch 1/200
# 3063/3064 [============================>.] - ETA: 0s - loss: 0.3503 - accuracy: 0.8707
# Epoch 1: val_accuracy did not improve from 0.58530
# 3064/3064 [==============================] - 126s 39ms/step - loss: 0.3503 - accuracy: 0.8707 - val_loss: 1.4830 - val_accuracy: 0.5688
# Epoch 2/200
# 2359/3064 [======================>.......] - ETA: 25s - loss: 0.3442 - accuracy: 0.8727
